# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd .read_csv('crcCASc.csv')

# %%
df
# Out:
#               STATE/UT                CRIME HEAD   2001   2002   2003   2004  \
# 0       ANDHRA PRADESH             MURDER OF SCs     45     60     33     39
# 1    ARUNACHAL PRADESH             MURDER OF SCs      0      0      0      0
# 2                ASSAM             MURDER OF SCs      0      3      8      0
# 3                BIHAR             MURDER OF SCs     28     33      9     14
# 4         CHHATTISGARH             MURDER OF SCs      8     11     12     25
# ..                 ...                       ...    ...    ...    ...    ...
# 413              DELHI  TOTAL CRIMES AGAINST SCs     19     16     13      4
# 414        LAKSHADWEEP  TOTAL CRIMES AGAINST SCs      0      0      0      0
# 415         PUDUCHERRY  TOTAL CRIMES AGAINST SCs     13     18     22     23
# 416        TOTAL (UTs)  TOTAL CRIMES AGAINST SCs     35     34     36     27
# 417  TOTAL (ALL-INDIA)  TOTAL CRIMES AGAINST SCs  33501  33507  26252  26887
#
# ...

# %%
df.shape
# Out:
# (418, 14)

# %%
df = df.loc[:, ~df.columns.isin([str(i) for i in range(2001, 2006)])]

# %%
df
# Out:
#               STATE/UT                CRIME HEAD   2006   2007   2008   2009  \
# 0       ANDHRA PRADESH             MURDER OF SCs     52     46     48     35
# 1    ARUNACHAL PRADESH             MURDER OF SCs      0      0      0      0
# 2                ASSAM             MURDER OF SCs      5     11      9      0
# 3                BIHAR             MURDER OF SCs     16     26     46     22
# 4         CHHATTISGARH             MURDER OF SCs     10     11      7     11
# ..                 ...                       ...    ...    ...    ...    ...
# 413              DELHI  TOTAL CRIMES AGAINST SCs     21     24     34     33
# 414        LAKSHADWEEP  TOTAL CRIMES AGAINST SCs      0      0      0      0
# 415         PUDUCHERRY  TOTAL CRIMES AGAINST SCs     14     25     29     29
# 416        TOTAL (UTs)  TOTAL CRIMES AGAINST SCs     40     49     66     65
# 417  TOTAL (ALL-INDIA)  TOTAL CRIMES AGAINST SCs  27070  30031  33430  33412
#
#       2010   2011   2012
# ...

# %%
df.shape
# Out:
# (418, 9)

# %%
df.head(20)
# Out:
#              STATE/UT     CRIME HEAD  2006  2007  2008  2009  2010  2011  2012
# 0      ANDHRA PRADESH  MURDER OF SCs    52    46    48    35    43    64    54
# 1   ARUNACHAL PRADESH  MURDER OF SCs     0     0     0     0     0     0     0
# 2               ASSAM  MURDER OF SCs     5    11     9     0     0     0     0
# 3               BIHAR  MURDER OF SCs    16    26    46    22    24    29    27
# 4        CHHATTISGARH  MURDER OF SCs    10    11     7    11     8     2     6
# 5                 GOA  MURDER OF SCs     0     0     0     0     0     0     0
# 6             GUJARAT  MURDER OF SCs    20    17    13    20    15    12    23
# 7             HARYANA  MURDER OF SCs     7    10     6     7    13    14    19
# 8    HIMACHAL PRADESH  MURDER OF SCs     0     0     0     1     0     1     0
# 9     JAMMU & KASHMIR  MURDER OF SCs     0     0     0     0     0     0     0
# 10          JHARKHAND  MURDER OF SCs     5    13     7     5     4     4     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE/UT    418 non-null    object
#  1   CRIME HEAD  418 non-null    object
#  2   2006        418 non-null    int64
#  3   2007        418 non-null    int64
#  4   2008        418 non-null    int64
#  5   2009        418 non-null    int64
#  6   2010        418 non-null    int64
#  7   2011        418 non-null    int64
#  8   2012        418 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 29.5+ KB

# %%
df.isnull().sum()
# Out:
# STATE/UT      0
# CRIME HEAD    0
# 2006          0
# 2007          0
# 2008          0
# 2009          0
# 2010          0
# 2011          0
# 2012          0
# dtype: int64

# %%
#Sum for each year
total_per_year=df.loc[:,'2006':'2012'].sum()
print(total_per_year)
# Out:
# 2006    162420
# 2007    180186
# 2008    200580
# 2009    200472
# 2010    195858
# 2011    202314
# 2012    201930
# dtype: int64

# %%
import matplotlib.pyplot as plt

total_per_year.plot(kind='bar', color='skyblue')
plt.title('Total Crimes Against SCs (2006–2012)')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %%
df['Total_2006_2012'] = df.loc[:, '2006':'2012'].sum(axis=1)
df.loc[:, 'Total_2006_2012'] = df.loc[:, '2006':'2012'].sum(axis=1)
# Make sure you're working on a fresh copy
df = df.copy()

# %%
# Add total crimes column
df['Total_2006_2012'] = df.loc[:, '2006':'2012'].sum(axis=1)

# %%
# Group by STATE/UT and sort
state_totals = df.groupby('STATE/UT')['Total_2006_2012'].sum().sort_values(ascending=False)
print(state_totals.head(5))
# Out:
# STATE/UT
# TOTAL (ALL-INDIA)    447920
# TOTAL (STATES)       447148
# UTTAR PRADESH         93622
# RAJASTHAN             66182
# ANDHRA PRADESH        54340
# Name: Total_2006_2012, dtype: int64

# %%
# Plot top 5 states
state_totals.head(5).plot(kind='bar', color='orange')
plt.title('Top 5 States by Crimes Against SCs (2006–2012)')
plt.xlabel('State/UT')
plt.ylabel('Total Crimes')
plt.show()

# %%
# Create pivot table: States vs Years
pivot_df = df.pivot_table(index='STATE/UT', values=['2006','2007','2008','2009','2010','2011','2012'], aggfunc='sum')

plt.figure(figsize=(12, 20))
sns.heatmap(pivot_df, cmap='YlOrRd', linewidths=0.5)
plt.title('Heatmap: Crimes Against SCs by State and Year (2006–2012)')
plt.xlabel('Year')
plt.ylabel('State/UT')
plt.show()

# %%
 Conclusion

No missing values were found in the dataset.
 Data from 2006 to 2012 was analyzed.
Total crimes per year show the overall trend.
Top 5 states with the highest crimes were identifiedA heatmap visualizes the variation of crimes by state and year.
This helps target specific states and years with higher crime rates for better policy making.
