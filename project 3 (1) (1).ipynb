# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd .read_csv('DataScientist.csv')

# %%
df
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# ...

# %%
df.shape
# Out:
# (3909, 17)

# %%
df.head(10)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
# 5           5      5                     Data Scientist
# 6           6      6            Quantitative Researcher
# 7           7      7    Quantitative Research Associate
# 8           8      8                       AI Scientist
# 9           9      9            Quantitative Researcher
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
# 5  $111K-$181K (Glassdoor est.)
# 6  $111K-$181K (Glassdoor est.)
# 7  $111K-$181K (Glassdoor est.)
# 8  $111K-$181K (Glassdoor est.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   Job Title          3909 non-null   object
#  3   Salary Estimate    3909 non-null   object
#  4   Job Description    3909 non-null   object
#  5   Rating             3909 non-null   float64
#  6   Company Name       3909 non-null   object
#  7   Location           3909 non-null   object
#  8   Headquarters       3909 non-null   object
#  9   Size               3909 non-null   object
#  10  Founded            3909 non-null   int64
#  11  Type of ownership  3909 non-null   object
#  12  Industry           3909 non-null   object
#  13  Sector             3909 non-null   object
#  14  Revenue            3909 non-null   object
#  15  Competitors        3909 non-null   object
# ...

# %%
# Check missing values
print(df.isnull().sum())
# Out:
# Unnamed: 0           0
# index                0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
df.loc[df['Rating'] < 0, 'Rating'] = np.nan
df.loc[df['Founded'] < 0, 'Founded'] = np.nan
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Unnamed: 0             0
# index                  0
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating               409
# Company Name           0
# Location               0
# Headquarters           0
# Size                   0
# Founded              977
# Type of ownership      0
# Industry               0
# Sector                 0
# Revenue                0
# Competitors            0
# Easy Apply             0
# dtype: int64

# %%
sns.histplot(df['Rating'].dropna(), bins=20, kde=True, color='teal')
plt.title('Distribution of Company Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
sns.barplot(data=job_counts, y='Job Title', x='Count', color=sns.color_palette('viridis', 1)[0])
# Out:
# <Axes: xlabel='Count', ylabel='Job Title'>

# %%
sns.countplot(y='Size', data=df, order=df['Size'].value_counts().index,
              color=sns.color_palette('magma', 1)[0])

plt.title('Job Count by Company Size')
plt.xlabel('Count')
plt.ylabel('Company Size')
plt.show()

# %%
sns.histplot(df['Founded'].dropna(), bins=30, kde=True, color='coral')
plt.title('Company Founded Year Distribution')
plt.xlabel('Year Founded')
plt.ylabel('Number of Companies')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare data for top 10 industries
industry_counts = df['Industry'].value_counts().head(10).reset_index()
industry_counts.columns = ['Industry', 'Job Count']

# Create the barplot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=industry_counts,
    y='Industry',
    x='Job Count',
    color='skyblue' ) # Use a single color instead of palette to avoid hue warning
# Out:
# <Axes: xlabel='Job Count', ylabel='Industry'>

# %%
Conclusion
Company ratings mostly range between 3.0 and 4.5.
️Popular job titles include Data Scientist, Data Analyst, Manager roles.️
Mid-sized and large companies are major employers.
️Most companies were founded in recent decades.
️Top industries: Travel, Consumer Services, Internet, and Marketing.
